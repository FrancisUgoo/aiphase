# %%
from openai import OpenAI

# %%
openai_client = OpenAI()

# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
import os

# %%
os.getenv('MY_TEST_SECRET_KEY')
# Out:
# 'lol'
